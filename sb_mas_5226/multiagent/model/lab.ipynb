# %%
from IPython.display import Image
import random
import numpy as np


"""
1. You may augment the observation space for all agents with the occupancy state of 
all cells or chosen cells in the agent’s immediate 8-neighbourhood (unoccupied, occupied)

2. As per previous entry, only cells that contain  an agent going in the opposite 
direction (as defined above) will be marked as occupied.
"""

# %%
Image(filename="/home/emeka/.Monash/s125/mas/a1/mas_a1_1.png")

# %%
Image(filename="/home/emeka/.Monash/s125/mas/a1/mas_a1_2.png")

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 # import picture here
# ----> 2 display.display_png("/home/emeka/Pictures/Screenshots/Screenshot from 2025-04-10 14-33-39.png")
#
# AttributeError: 'function' object has no attribute 'display_png'

# %%
possible_states = {"city": 1, "dead": 0, "shelter": 2, "market": 3, "home": 4}
actions = ["north", "south", "east", "west"]

# %%
# calculate next TD-Target

# example    
    # 1+0.1[0.4+0.95*2(-1)]
updating_q_matrix = update_q_matrix()
def tdValue(state: str, action: str):
    possible_states[state]
    for s1, s2 in range(possible_states):
        if action == "run":
            q_val_run = np.matmul(updating_q_matrix[s1][s2], r_matrix[s1])+learning_rate*(r_matrix[s1] + gamma*max())
            policy.update(q_val_run)
            update_q_matrix()
            break
        elif action == "stay":
            q_value_stay = np.matmul(q_matrix[s1][s2], r_matrix[s1])
            policy.update(q_value_stay)
            update_q_matrix()

# %%
def maximize(agent):
    pass

# %%
class GridWorld:
    def __init__(self, n: int, m: int):
        grid = np.zeros([n, m])
        agent_position = ((0,0))
        
    def populate_agents(self, num_agents: set):
        pos = self.agent_position
        for i in range(num_agents):
            dx = random.randint(1,self.n)
            dy = random.randint(1, self.m)
            pos.add((dx, dy))
        return pos
    
    
        
        
        
        
        
        
    """THIS SECTION CONCERNS Q-TABLES"""
    q_matrix = None
    def update_q_matrix(q_matrix):
        # initialie for q(s',a') consider all 0's
        # research done on initializeing vals
        q_matrix = np.random.rand(5,5)
        print(q_matrix)
        return q_matrix
        learning_rate = 0.1
        gamma = 0.95
        
        r_matrix = [0.5, 0.2, 0.3, 0.7, 0.0]
        agent = None
        # epsilon greedy (prefer a high value)
        policy = {}
            # 1+0.1[0.4+0.95*2(-1)]
    updating_q_matrix = update_q_matrix()
    def tdValue(state: str, action: str):
        possible_states[state]
        for s1, s2 in range(possible_states):
            if action == "run":
                q_val_run = np.matmul(updating_q_matrix[s1][s2], r_matrix[s1])+learning_rate*(r_matrix[s1] + gamma*max())
                policy.update(q_val_run)
                update_q_matrix()
                break
            elif action == "stay":
                q_value_stay = np.matmul(q_matrix[s1][s2], r_matrix[s1])
                policy.update(q_value_stay)
                update_q_matrix()
        
        
        
        
        
        
        
        
        
    def init(density):
        global config, empty, agents, unhappiness, avg_similarity, speed
        global unhappiness, avg_similarity
        speed = 1.0
        empty =[]
        agents=[]
        unhappiness=[]
        avg_similarity=[]
        config = np.zeros([height, width])
        for x in range(width):
            for y in range(height):
                if RD.random() < density:
                    agents.append((y, x))
                    if RD.random() < 0.5:
                        config[y, x] = 1
                    else:
                        config[y, x] = -1
                else:
                    config[y,x] = 0
                    empty.append((y, x))

# %%
class Agent:
    pass
